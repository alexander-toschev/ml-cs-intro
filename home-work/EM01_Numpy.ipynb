# %% [markdown]
# # HW01 / EM01 — NumPy в Google Colab / NumPy coding assignment
#
# **Первое ДЗ: программирование на NumPy. / First homework: NumPy programming.**
#
# RU: Откройте ноутбук в Colab, сохраните свою копию на Google Drive, заполните имя и группу, реализуйте семь задач. Используйте обычную среду Python 3 (CPU), GPU не нужен. NumPy уже доступен в Colab. Бюджет: до 4 академических часов (180 минут).
#
# EN: Open in Colab, save your own copy to Google Drive, fill in your name/group, and implement seven tasks. Use the standard Python 3 CPU runtime; no GPU is needed. NumPy is available in Colab. Time budget: up to 180 minutes.
#
# RU: Перед сдачей перезапустите среду и выполните все ячейки сверху вниз. Скачайте `.ipynb` с результатами и сдайте в Moodle; ссылка Colab с доступом преподавателю — дополнительно. Дедлайн задаёт преподаватель в Moodle. В этом ноутбуке нет штрафа по локальному времени.
#
# EN: Restart the runtime and run all cells before submission. Download the executed `.ipynb` and submit in Moodle; optionally include a Colab link accessible to the instructor. The deadline is set in Moodle. This notebook does not apply local-clock late penalties.
#
# **Самопроверка / Self-check: 100 баллов / points.** Проверки открытые, преподаватель дополнительно проверяет код и векторизацию. / Checks are public; the instructor also reviews the code and vectorisation.

# %%
import numpy as np

full_name = ""  # Ваше имя / Your name
student_group = ""  # Группа / Group
assignment_id = "EM01_Numpy"
print("NumPy:", np.__version__)

# %% [markdown]
# ## T1 — Массив / Array (10)
#
# Создайте `arr1`: ndarray формы `(10,)` со значениями 0…9 через NumPy. / Create `arr1`, an ndarray of shape `(10,)` containing 0…9 using NumPy.

# %%
arr1 = None  # TODO

# %% [markdown]
# ## T2 — Сумма квадратов / Sum of squares (15)
#
# Реализуйте `sum_of_squares(a)`: сумму квадратов всех элементов числового массива любой формы. Без циклов, comprehensions и `np.vectorize`. Вход не изменять; пустой массив даёт 0. / Return the sum of squares of all elements of a numeric array of any shape, without loops, comprehensions or `np.vectorize`. Do not modify the input; an empty array returns 0.

# %%
def sum_of_squares(a):
    raise NotImplementedError("TODO")

# %% [markdown]
# ## T3 — Диагонали / Diagonals (15)
#
# Создайте ndarray `D` формы `(5,5)`: главная диагональ 1, побочная 2, центр 3, остальные элементы 0. Используйте операции NumPy, без ручного перечисления 25 элементов. / Create a `(5,5)` ndarray `D`: main diagonal 1, secondary diagonal 2, centre 3, other entries 0. Use NumPy operations rather than hardcoding 25 values.

# %%
D = None  # TODO

# %% [markdown]
# ## T4 — Broadcasting (15)
#
# Реализуйте `broadcast_op(x,y) = x*y + x + y` для массивов форм `(n,1)` и `(1,m)`. Результат `(n,m)`. Без циклов, `tile`, `repeat` и изменения входов. / Implement the formula for shapes `(n,1)` and `(1,m)`, returning `(n,m)`. Use broadcasting, without loops, `tile`, `repeat` or input mutation.

# %%
def broadcast_op(x, y):
    raise NotImplementedError("TODO")

# %% [markdown]
# ## T5 — Маска / Boolean mask (15)
#
# Верните среднее элементов `z`, строго больших среднего всего `z`. Если таких элементов нет или массив пуст, верните `np.nan`. Вход — конечные числа, без NaN/inf. Используйте булеву маску, без циклов, вход не изменять. / Return the mean of elements strictly above the overall mean. Return `np.nan` if none qualify or the array is empty. Inputs contain finite numbers. Use a boolean mask, no loops or input mutation.

# %%
def mean_above_mean(z):
    raise NotImplementedError("TODO")

# %% [markdown]
# ## T6 — Линейная система / Linear system (20)
#
# Решите `A @ x = b` с помощью `np.linalg.solve`, без вычисления обратной матрицы. `A` — невырожденная квадратная матрица `(n,n)`, `b` — вектор `(n,)`; вернуть ndarray `(n,)`, не менять входы. / Solve using `np.linalg.solve`, without matrix inversion. `A` is a nonsingular square matrix and `b` a vector. Return an ndarray of shape `(n,)` without mutating inputs.

# %%
def solve_linear(A, b):
    raise NotImplementedError("TODO")

# %% [markdown]
# ## T7 — Reshape и срез / Reshape and slice (10)
#
# Функция `row2_rev()` создаёт числа 1…24, меняет форму на `(4,6)` и возвращает вторую строку в обратном порядке срезом. Ожидается `[12,11,10,9,8,7]`. Не прописывайте ответ вручную. / Create 1…24, reshape to `(4,6)`, and return the second row reversed using slicing. Do not hardcode the result.

# %%
def row2_rev():
    raise NotImplementedError("TODO")

# %% [markdown]
# ## Краткое объяснение / Short explanation
#
# В этой ячейке объясните: (1) как формы в T4 дают `(n,m)`; (2) что делает маска в T5; (3) какие источники или AI-помощь использовали. / Explain (1) why T4 produces `(n,m)`, (2) how the T5 mask works, and (3) any sources or AI assistance used.
#
# **Ваш ответ / Your answer:** …

# %% [markdown]
# ## Самопроверка / Self-check
#
# RU: Выполните после решений. Несделанная задача получает 0, остальные продолжают проверяться. Повторный запуск сбрасывает баллы. Не меняйте проверки для повышения балла. Число `score` — результат открытой самопроверки, не защищённая оценка преподавателя.
#
# EN: Run after your solutions. Unimplemented tasks get 0 without blocking the rest. Rerunning resets the score. Do not edit checks to increase your score. The reported score is a public self-check, not a tamper-proof instructor grade.

# %%
import json

def equal_array(got, expected):
    return (isinstance(got, np.ndarray) and got.shape == expected.shape
            and np.allclose(got, expected, rtol=1e-7, atol=1e-9, equal_nan=True))

def scalar_close(got, expected):
    return np.ndim(got) == 0 and bool(np.isclose(got, expected, equal_nan=True))

def check_t1():
    return equal_array(arr1, np.arange(10))

def check_t2():
    for a, expected in [(np.array([-2., 0., 3.]), 13.),
                        (np.array([[1., 2.], [-3., 4.]]), 30.),
                        (np.array([]), 0.)]:
        old = a.copy()
        if not scalar_close(sum_of_squares(a), expected) or not np.array_equal(a, old):
            return False
    return True

def check_t3():
    return equal_array(D, np.array([[1,0,0,0,2],[0,1,0,2,0],
                                   [0,0,3,0,0],[0,2,0,1,0],[2,0,0,0,1]]))

def check_t4():
    for n, m in [(5,4), (2,3), (1,1)]:
        x = np.arange(n, dtype=float).reshape(n,1) - 2
        y = np.arange(m, dtype=float).reshape(1,m) / 2
        old_x, old_y = x.copy(), y.copy()
        expected = x*y + x + y
        if not equal_array(broadcast_op(x,y), expected):
            return False
        if not np.array_equal(x, old_x) or not np.array_equal(y, old_y):
            return False
    return True

def check_t5():
    for z, expected in [(np.array([1.,2.,3.,10.]),10.),
                        (np.array([-4.,-2.,0.,2.]),1.),
                        (np.array([3.,3.,3.]),np.nan),
                        (np.array([]),np.nan)]:
        old = z.copy()
        if not scalar_close(mean_above_mean(z), expected) or not np.array_equal(z, old):
            return False
    return True

def check_t6():
    for A, expected in [(np.array([[3.,1.],[1.,2.]]),np.array([2.,-1.])),
                        (np.array([[4.,1.,0.],[1.,3.,1.],[0.,1.,2.]]),np.array([1.,-2.,3.]))]:
        b = A @ expected
        old_A, old_b = A.copy(), b.copy()
        if not equal_array(solve_linear(A,b), expected):
            return False
        if not np.array_equal(A,old_A) or not np.array_equal(b,old_b):
            return False
    return True

def check_t7():
    return equal_array(row2_rev(),np.array([12,11,10,9,8,7]))

results = []
for name, points, check in [("T1",10,check_t1),("T2",15,check_t2),
                             ("T3",15,check_t3),("T4",15,check_t4),
                             ("T5",15,check_t5),("T6",20,check_t6),
                             ("T7",10,check_t7)]:
    try:
        ok = bool(check())
        detail = "OK" if ok else "FAIL: check values, shapes and input mutation"
    except Exception as exc:
        ok = False
        detail = type(exc).__name__ + ": " + str(exc)
    earned = points if ok else 0
    results.append({"task":name,"score":earned,"max":points})
    print(f"{name}: {earned}/{points} — {detail}")

if not full_name.strip() or not student_group.strip():
    print("Заполните имя и группу перед сдачей / Fill in your name and group before submission")
raw_score = sum(item["score"] for item in results)
final = {"name":full_name,"group":student_group,"assignment":assignment_id,
         "score":raw_score,"max_score":100,"kind":"self_check","tasks":results}
print(json.dumps(final, ensure_ascii=False))
