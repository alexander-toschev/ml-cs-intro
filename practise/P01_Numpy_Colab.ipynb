# %% [markdown]
# # P01 — NumPy: практика в Google Colab / Guided Colab practice
#
# 90 минут: 0–10 запуск и копия; 10–30 массивы и срезы; 30–50 оси и маски; 50–70 broadcasting; 70–85 линейная система; 85–90 перезапуск и все ячейки.
#
# 90 minutes: setup/copy (10), arrays/slicing (20), axes/masks (20), broadcasting (20), linear system (15), restart/run all (5).
#
# Создайте копию в Google Drive. Запускайте примеры и выполняйте мини-задания. CPU достаточно. Практика формирующая, без отдельного балла; затем решите HW01 самостоятельно.
#
# Save a copy to Drive, run the examples and complete the mini-exercises. CPU is sufficient. This is ungraded guided practice; then complete HW01 independently.

# %%
import numpy as np
print(np.__version__)

# %% [markdown]
# ## 1. Массивы и срезы / Arrays and slices

# %%
a = np.arange(12).reshape(3,4)
print(a)
print(a.shape, a.dtype)
print(a[0, ::2])

# %% [markdown]
# Выведите последний столбец и первые две строки. / Print the last column and the first two rows.

# %%
# TODO

# %% [markdown]
# ## 2. Оси и маски / Axes and masks

# %%
data = np.array([[2.,4.,6.],[1.,3.,8.]])
print(data.mean(axis=0))
print(data.mean(axis=1))
mask = data > 4
print(mask)
print(data[mask])

# %% [markdown]
# Найдите сумму каждого столбца и элементы меньше 3. / Find each column sum and elements below 3.

# %%
# TODO

# %% [markdown]
# ## 3. Broadcasting

# %%
x = np.array([[1.],[2.],[3.]])
y = np.array([[10.,20.]])
print(x.shape, y.shape)
print(x+y)

# %% [markdown]
# Вычтите из каждого столбца `data` его среднее; проверьте, что средние стали нулевыми. / Centre each column of `data` and verify its mean is zero.

# %%
# TODO

# %% [markdown]
# ## 4. Линейная система / Linear system

# %%
A = np.array([[2.,1.],[1.,3.]])
b = np.array([4.,7.])
solution = np.linalg.solve(A,b)
print(solution)
print(np.allclose(A @ solution,b))

# %% [markdown]
# Измените `b` на `[1.,5.]`, решите снова и проверьте результат подстановкой. / Change `b` to `[1.,5.]`, solve again and verify by substitution.

# %%
# TODO

# %% [markdown]
# ## Дальше / Next
#
# [HW01 — NumPy](https://colab.research.google.com/github/alexander-toschev/ml-cs-intro/blob/main/home-work/EM01_Numpy.ipynb)
